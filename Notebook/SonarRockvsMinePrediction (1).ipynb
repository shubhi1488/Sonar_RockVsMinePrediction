# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection & data Preprocessing

# %%
#loading the dataset to a pandas dataframe
sonar_data=pd.read_csv("/content/Copy of sonar data.csv",header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
#number of rows and columns
sonar_data.shape
# Out:
# (208, 61)

# %%
#statistical data
sonar_data.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
#find how many examples are there for rocks and mines
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %% [markdown]
# M-->Mine R-->Rock

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
#separating the data and the labels
X=sonar_data.drop(columns=60,axis=1)#we are dropping the column so axis=1
Y=sonar_data[60]

# %%
print(X)
print(Y)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
#splitting the data into train and test set
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,stratify=Y,random_state=1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %%
#train our model
model=LogisticRegression()

# %%
#trainig the model with training data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#evaluate the model
#accuracy on training data
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print("Accuracy on training data:",training_data_accuracy)
# Out:
# Accuracy on training data: 0.8342245989304813

# %%
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print("Accuracy on test data:",test_data_accuracy)
# Out:
# Accuracy on test data: 0.7619047619047619

# %%
#making the predictive system to predict whether it is rock or mine
#changing the input_data to numpy array
input_data=(0.0190,0.0038,0.0642,0.0452,0.0333,0.0690,0.0901,0.1454,0.0740,0.0349,0.1459,0.3473,0.3197,0.2823,0.0166,0.0572,0.2164,0.4563,0.3819,0.5627,0.6484,0.7235,0.8242,0.8766,1.0000,0.8582,0.6563,0.5087,0.4817,0.4530,0.4521,0.4532,0.5385,0.5308,0.5356,0.5271,0.4260,0.2436,0.1205,0.3845,0.4107,0.5067,0.4216,0.2479,0.1586,0.1124,0.0651,0.0789,0.0325,0.0070,0.0026,0.0093,0.0118,0.0112,0.0094,0.0140,0.0072,0.0022,0.0055,0.0122)
input_data_as_numpy_array=np.asarray(input_data)
#reshape the numpy array as we are predicting for one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction=model.predict(input_data_reshaped)
print(prediction)
if(prediction[0]=='R'):
  result='Rock'
else:
  result='Mine'
# Out:
# ['R']

# %%
print('Prediction Result:', result)

# Create dataframe for result
result_df = pd.DataFrame({
    'Prediction': [result]
})

# Save result into CSV file
result_df.to_csv('prediction_result.csv', index=False)

print('Prediction result saved successfully as prediction_result.csv')
# Out:
# Prediction Result: Rock
# Prediction result saved successfully as prediction_result.csv

# %%
import pickle

# Save the trained model
filename = 'sonar_model.pkl'

with open(filename, 'wb') as file:
    pickle.dump(model, file)

print('Model saved successfully as sonar_model.pkl')
# Out:
# Model saved successfully as sonar_model.pkl

# %%
# Load the saved model
loaded_model = pickle.load(open('sonar_model.pkl', 'rb'))

# Test prediction using loaded model
prediction = loaded_model.predict(input_data_reshaped)

print(prediction)
# Out:
# ['R']

# %%
from google.colab import files

# Download CSV file
files.download('prediction_result.csv')

# Download PKL model
files.download('sonar_model.pkl')

# %%
import gradio as gr
import numpy as np
import pickle

# Load the saved model
loaded_model = pickle.load(open('sonar_model.pkl', 'rb'))

# Prediction function
def sonar_prediction(input_data):

    # Convert input string into list of float values
    input_data = [float(x) for x in input_data.split(',')]

    # Convert into numpy array
    input_data_as_numpy_array = np.asarray(input_data)

    # Reshape the array
    input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

    # Prediction
    prediction = loaded_model.predict(input_data_reshaped)

    # Output
    if prediction[0] == 'R':
        return "The Object is a Rock"
    else:
        return "The Object is a Mine"


# Gradio Interface
interface = gr.Interface(
    fn=sonar_prediction,
    inputs=gr.Textbox(
        lines=4,
        placeholder="Enter 60 comma-separated sonar values",
        label="Sonar Input Values"
    ),
    outputs=gr.Textbox(label="Prediction Result"),
    title="Sonar Rock vs Mine Prediction",
    description="Enter 60 sonar values separated by commas to predict whether the object is a Rock or Mine."
)

# Launch app
interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://751fe5a88b144f1561.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://751fe5a88b144f1561.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
